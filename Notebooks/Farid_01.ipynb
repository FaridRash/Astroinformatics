5.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J222601.36+001544.5.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J222627.78-005011.1.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J222638.29-003449.6.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J222751.89+000457.1.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J222821.19+011410.4.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J223007.48-000011.0.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J223032.64+002033.0.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J223245.54-004032.8.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J223440.03-000515.2.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J223814.86-084119.2.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J223822.19-093742.4.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J223949.39-091232.4.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J224107.33+005737.0.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J224429.25-000018.3.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J224530.53+002815.6.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J224552.42+002751.8.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J224555.28+003909.1.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J224810.88-002343.4.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J224819.44-003641.6.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J224855.25-003650.9.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J224935.81-011232.0.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J225125.87-092635.9.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J225203.73-005750.3.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J225213.51-101545.8.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J225214.65-000232.1.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J225521.48-005651.9.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J225537.67-001518.0.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J225640.85-002452.8.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J225653.88-103102.9.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J225828.42+010851.7.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J225852.54-004547.6.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J230145.18-004760.0.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J230320.46-004614.2.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J230338.96-101619.6.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J230400.39-004801.3.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J230603.83+000626.2.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J230645.34-010126.2.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J231059.50-102013.7.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J231426.07-084336.8.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J231449.90-102354.3.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J231626.48+003318.7.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J231646.54-101711.3.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J231822.48-090835.6.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J231927.19-084303.0.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J232223.60+010630.1.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J232307.12+002933.3.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J232410.15+001314.7.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J232413.16-002208.3.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J232418.51-104035.8.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J232643.28+010803.2.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J232728.92+003740.7.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J232748.29+005752.6.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J232838.49-103557.3.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J233024.26-095508.4.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J233030.67-005339.7.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J233037.71-083846.4.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J233200.21+010205.9.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J233305.67+002703.9.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J233340.49-100405.8.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J233428.55+003419.0.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J233515.92-011216.8.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J233556.81-091109.1.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J233740.20+001640.8.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J233748.10+001420.9.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J233953.63-090248.7.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J234017.14+004008.8.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J234152.22-005213.0.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J234318.21-101750.5.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J234625.76+001605.1.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J234819.50-000855.9.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J234937.06-002848.5.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J235040.29+000506.8.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J235116.60-091206.4.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J235603.02+003944.8.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J235753.99-094746.4.jpg
#   inflating: /content/Astroinformatics/Data/FRI/J235842.07-095436.0.jpg

# %% [markdown]
# #**Libraries**

# %%
# !pip install imutils
# Out:
# Requirement already satisfied: imutils in /usr/local/lib/python3.12/dist-packages (0.5.4)

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly) (9.1.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly) (26.0)

# %%
import cv2
import time
import random
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from imutils import paths
from tensorflow import keras
import matplotlib.pyplot as plt
from collections import Counter
from tensorflow.nn import softmax
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from skimage.metrics import structural_similarity as ssim
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %% [markdown]
# ##GPU testing

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# []

# %% [markdown]
# #**Data**

# %% [markdown]
# ##Fetching

# %%
# Reading FR0 Images
imagePaths = list(paths.list_images(r"/content/Astroinformatics/Data/FR0"))

data = []
data_cropped = []
labels = []
label = 0
counter_0 = 0

for imagePath in imagePaths:
  image = tf.io.read_file(imagePath)
  image = tf.image.decode_image(image, channels=1)
  data.append(image)
  labels.append(label)
  counter_0 += 1
print(f'Loaded FR0... {counter_0} files has loaded.')
# Out:
# Loaded FR0... 6066 files has loaded.

# %%
# Reading FRI Images
imagePaths = list(paths.list_images(r"/content/Astroinformatics/Data/FRI"))


label = 1
counter_1 = 0

for imagePath in imagePaths:
  image = tf.io.read_file(imagePath)
  image = tf.image.decode_image(image, channels=1)
  data.append(image)
  labels.append(label)
  counter_1 += 1
print(f'Loaded FRI... {counter_1} files has loaded.')
# Out:
# Loaded FRI... 5008 files has loaded.

# %%
# Reading FRII Images
imagePaths = list(paths.list_images(r"/content/Astroinformatics/Data/FRII"))

label = 2
counter_2 = 0

for imagePath in imagePaths:
  image = tf.io.read_file(imagePath)
  image = tf.image.decode_image(image, channels=1)
  data.append(image)
  labels.append(label)
  counter_2 += 1
print(f'Loaded FRII... {counter_2} files has loaded.')
# Out:
# Loaded FRII... 2066 files has loaded.

# %% [markdown]
# ##Cropping

# %%
data_cropped = []
for image in data:
  image = tf.image.crop_to_bounding_box(image, 120, 120, 60, 60)
  data_cropped.append(image)

# %% [markdown]
# ##Data Distribution

# %%
counter = Counter(labels)
sorted_counts = dict(sorted(counter.items()))
plt.bar(sorted_counts.keys(), sorted_counts.values(), color='skyblue')
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Count of Each Class in the Dataset')
plt.xticks(range(3))
plt.show()

# %% [markdown]
# ##Converting the lists to a NumPy array

# %%
labels = np.array(labels,dtype='uint8')
data = np.array(data,dtype='uint8')
data_cropped = np.array(data_cropped,dtype='uint8')

# %% [markdown]
# #**EDA**

# %% [markdown]
# ##Displaying sample images

# %%
class_0 = data[labels == 0]
image = np.squeeze(class_0[1])
plt.subplot(1, 3, 1)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(f"Image at FR0")

class_1 = data[labels == 1]
image = np.squeeze(class_1[1])
plt.subplot(1, 3, 2)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(f"Image at FRI")

class_2 = data[labels == 2]
image = np.squeeze(class_2[1])
plt.subplot(1, 3, 3)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(f"Image at FRII")


plt.show()

# %%
class_0 = data_cropped[labels == 0]
image = np.squeeze(class_0[1])
plt.subplot(1, 3, 1)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(f"Image at FR0")

class_1 = data_cropped[labels == 1]
image = np.squeeze(class_1[1])
plt.subplot(1, 3, 2)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(f"Image at FRI")

class_2 = data_cropped[labels == 2]
image = np.squeeze(class_2[1])
plt.subplot(1, 3, 3)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(f"Image at FRII")


plt.show()

# %% [markdown]
# ##Filterring

# %%
data_cropped.shape, labels.shape
# Out:
# ((13140, 60, 60, 1), (13140,))

# %%
mask = np.array([np.max(image) >= 5 for image in data_cropped])
filtered_data = data_cropped[mask]
filtered_labels = labels[mask]

# %%
mask_useless = np.array([np.max(image) < 5 for image in data_cropped])
useless_data = data_cropped[mask_useless]
useless_labels = labels[mask_useless]

# %%
class_0_useless = useless_data[useless_labels == 0]
class_1_useless = useless_data[useless_labels == 1]
class_2_useless = useless_data[useless_labels == 2]

# %%
np.max(class_0_useless), np.max(class_1_useless), np.max(class_2_useless)
# Out:
# (np.uint8(2), np.uint8(0), np.uint8(2))

# %%
class_0_useless.shape, class_1_useless.shape, class_2_useless.shape
# Out:
# ((94, 60, 60, 1), (40, 60, 60, 1), (36, 60, 60, 1))

# %%
temp = 0
for i in class_0_useless:
  if np.max(i) >temp:
    temp = np.max(i)
    image = np.squeeze(i)
plt.subplot(1, 3, 1)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(f"Image at FR0")

temp = 0
for i in class_1_useless:
  if np.max(i) >temp:
    temp = np.max(i)
    image = np.squeeze(i)
plt.subplot(1, 3, 2)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(f"Image at FRI")

temp = 0
for i in class_2_useless:
  if np.max(i) >temp:
    temp = np.max(i)
    image = np.squeeze(i)
plt.subplot(1, 3, 3)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(f"Image at FRII")


plt.show()

# %%
counter = Counter(filtered_labels)
sorted_counts = dict(sorted(counter.items()))
plt.bar(sorted_counts.keys(), sorted_counts.values(), color='skyblue')
plt.grid(True)
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Count of Each Class in the Dataset')
plt.xticks(range(3))
plt.show()

# %%
class_0_image = filtered_data[filtered_labels == 0]
class_1_image = filtered_data[filtered_labels == 1]
class_2_image = filtered_data[filtered_labels == 2]
class_0_image.shape, class_1_image.shape, class_2_image.shape
# Out:
# ((5972, 60, 60, 1), (4968, 60, 60, 1), (2030, 60, 60, 1))

# %% [markdown]
# ##Flattening

# %%
class_0_flatten = []
class_1_flatten = []
class_2_flatten = []


for image in final_data[final_labels == 0]:
    class_0_flatten.append(image.flatten())

for image in final_data[final_labels == 1]:
    class_1_flatten.append(image.flatten())

for image in final_data[final_labels == 2]:
    class_2_flatten.append(image.flatten())


class_0_flatten = np.array(class_0_flatten, dtype='uint8')
class_1_flatten = np.array(class_1_flatten, dtype='uint8')
class_2_flatten = np.array(class_2_flatten, dtype='uint8')

class_0_flatten.shape, class_1_flatten.shape, class_2_flatten.shape, final_data.shape, final_labels.shape
# Out:
# ((5972, 3600), (5968, 3600), (6030, 3600), (17970, 60, 60, 1), (17970,))

# %% [markdown]
# ##Displaing Flattened images

# %%
for i in range(5):
    plt.plot(class_0_flatten[i], color='red')

plt.show();

# %%
for i in range(5):
    plt.plot(class_1_flatten[i], color='red')

plt.show();

# %%
for i in range(5):
    plt.plot(class_2_flatten[i], color='red')

plt.show();

# %% [markdown]
# ##Pixels mean

# %%
class_0_median = np.median(class_0_flatten, axis=0)

plt.plot(class_0_median, color='green')
plt.show()

# %%
class_0_mean = np.mean(class_0_flatten, axis=0)

plt.plot(class_0_mean)
plt.show()

# %%
class_1_median = np.median(class_1_flatten, axis=0)

plt.plot(class_1_median, color='green')
plt.show()

# %%
class_1_mean = np.mean(class_1_flatten, axis=0)

plt.plot(class_1_mean)
plt.show()

# %%
class_2_median = np.median(class_2_flatten, axis=0)

plt.plot(class_2_median, color='green')
plt.show()

# %%
class_2_mean = np.mean(class_2_flatten, axis=0)

plt.plot(class_2_mean)
plt.show()

# %% [markdown]
# ##Pixels Correlation

# %%
correlation_matrix = np.corrcoef(class_0_flatten, rowvar=False)
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, cmap="coolwarm", vmin=-1, vmax=1)
plt.title("Pixel Correlation Matrix Across FR0")
plt.xlabel("Pixel Index")
plt.ylabel("Pixel Index")
plt.show()

# %%
correlation_matrix = np.corrcoef(class_1_flatten, rowvar=False)
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, cmap="coolwarm", vmin=-1, vmax=1)
plt.title("Pixel Correlation Matrix Across FRI")
plt.xlabel("Pixel Index")
plt.ylabel("Pixel Index")
plt.show()

# %%
correlation_matrix = np.corrcoef(class_2_flatten, rowvar=False)
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, cmap="coolwarm", vmin=-1, vmax=1)
plt.title("Pixel Correlation Matrix Across FRII")
plt.xlabel("Pixel Index")
plt.ylabel("Pixel Index")
plt.show()

# %% [markdown]
# ##Sobel

# %%
class_0_image = final_data[final_labels == 0]
class_1_image = final_data[final_labels == 1]
class_2_image = final_data[final_labels == 2]

# %%
class_0_image.shape, class_1_image.shape, class_2_image.shape
# Out:
# ((5972, 60, 60, 1), (5968, 60, 60, 1), (6030, 60, 60, 1))

# %%
sobel_x = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=5)
sobel_y = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=5)
edge_image = np.sqrt(sobel_x**2 + sobel_y**2)

plt.figure(figsize=(12, 6))
for i in range(3):
    image = class_0_image[i]
    sobel_x = cv2.Sobel(class_0_image[i], cv2.CV_64F, 1, 0, ksize=5)
    sobel_y = cv2.Sobel(class_0_image[i], cv2.CV_64F, 0, 1, ksize=5)
    edge_image = np.sqrt(sobel_x**2 + sobel_y**2)
    plt.subplot(2, 5, i+1)
    plt.imshow(image, cmap='gray')
    plt.title(f"Original FR0 {i+1}")
    plt.axis('off')

    plt.subplot(2, 5, i+6)
    plt.imshow(edge_image, cmap='gray')
    plt.title(f"Sobel Edges FR0 {i+1}")
    plt.axis('off')

# %%
sobel_x = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=5)
sobel_y = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=5)
edge_image = np.sqrt(sobel_x**2 + sobel_y**2)

plt.figure(figsize=(12, 6))
for i in range(3):
    image = class_1_image[i]
    sobel_x = cv2.Sobel(class_1_image[i], cv2.CV_64F, 1, 0, ksize=5)
    sobel_y = cv2.Sobel(class_1_image[i], cv2.CV_64F, 0, 1, ksize=5)
    edge_image = np.sqrt(sobel_x**2 + sobel_y**2)
    plt.subplot(2, 5, i+1)
    plt.imshow(image, cmap='gray')
    plt.title(f"Original FRI {i+1}")
    plt.axis('off')

    plt.subplot(2, 5, i+6)
    plt.imshow(edge_image, cmap='gray')
    plt.title(f"Sobel Edges FRI {i+1}")
    plt.axis('off')

# %%
sobel_x = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=5)
sobel_y = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=5)
edge_image = np.sqrt(sobel_x**2 + sobel_y**2)

plt.figure(figsize=(12, 6))
for i in range(1, 4):
    image = class_2_image[i]
    sobel_x = cv2.Sobel(class_2_image[i], cv2.CV_64F, 1, 0, ksize=5)
    sobel_y = cv2.Sobel(class_2_image[i], cv2.CV_64F, 0, 1, ksize=5)
    edge_image = np.sqrt(sobel_x**2 + sobel_y**2)
    plt.subplot(2, 5, i+1)
    plt.imshow(image, cmap='gray')
    plt.title(f"Original FRII {i+1}")
    plt.axis('off')

    plt.subplot(2, 5, i+6)
    plt.imshow(edge_image, cmap='gray')
    plt.title(f"Sobel Edges FRII {i+1}")
    plt.axis('off')

# %% [markdown]
# ##Symmetry

# %%
plt.figure(figsize=(12, 6))
for i in range(3):
    image = class_0_image[i]
    image = cv2.resize(image, (50, 50))

    flipped_image = cv2.flip(image, 1)

    symmetry_score, _ = ssim(image, flipped_image, full=True)


    # Original Image
    plt.subplot(3, 5, i+1)
    plt.imshow(image, cmap='gray')
    plt.title(f"FR0 {i+1}")
    plt.axis('off')

    # Flipped Image
    flipped_image = cv2.flip(image, 1)
    plt.subplot(3, 5, i+6)
    plt.imshow(flipped_image, cmap='gray')
    plt.title(f"Flipped FR0 {i+1}")
    plt.axis('off')

    # Symmetry Score
    plt.subplot(3, 5, i+11)
    plt.text(0.5, 0.5, f"SSIM: {symmetry_score:.2f}", ha='center', va='center', fontsize=12)
    plt.axis('off')

# %%
plt.figure(figsize=(12, 6))
for i in range(3):
    image = class_1_image[i]
    image = cv2.resize(image, (50, 50))

    flipped_image = cv2.flip(image, 1)

    symmetry_score, _ = ssim(image, flipped_image, full=True)


    # Original Image
    plt.subplot(3, 5, i+1)
    plt.imshow(image, cmap='gray')
    plt.title(f"FRI {i+1}")
    plt.axis('off')

    # Flipped Image
    flipped_image = cv2.flip(image, 1)
    plt.subplot(3, 5, i+6)
    plt.imshow(flipped_image, cmap='gray')
    plt.title(f"Flipped FRI {i+1}")
    plt.axis('off')

    # Symmetry Score
    plt.subplot(3, 5, i+11)
    plt.text(0.5, 0.5, f"SSIM: {symmetry_score:.2f}", ha='center', va='center', fontsize=12)
    plt.axis('off')

# %%
plt.figure(figsize=(12, 6))
for i in range(1, 4):
    image = class_2_image[i]
    image = cv2.resize(image, (50, 50))

    flipped_image = cv2.flip(image, 1)

    symmetry_score, _ = ssim(image, flipped_image, full=True)


    # Original Image
    plt.subplot(3, 5, i+1)
    plt.imshow(image, cmap='gray')
    plt.title(f"FRII {i+1}")
    plt.axis('off')

    # Flipped Image
    flipped_image = cv2.flip(image, 1)
    plt.subplot(3, 5, i+6)
    plt.imshow(flipped_image, cmap='gray')
    plt.title(f"Flipped FRII {i+1}")
    plt.axis('off')

    # Symmetry Score
    plt.subplot(3, 5, i+11)
    plt.text(0.5, 0.5, f"SSIM: {symmetry_score:.2f}", ha='center', va='center', fontsize=12)
    plt.axis('off')

# %%
flipped_class_0_scores = []

for i in class_0_image:
    image = cv2.resize(i, (50, 50))
    flipped_image = cv2.flip(image, 1)
    symmetry_score, _ = ssim(image, flipped_image, full=True)
    flipped_class_0_scores.append(symmetry_score)

flipped_class_0_scores = np.array(flipped_class_0_scores)
flipped_class_0_scores_mean = np.mean(flipped_class_0_scores)
flipped_class_0_scores.shape
# Out:
# (5972,)

# %%
flipped_class_1_scores = []

for i in class_1_image:
    image = cv2.resize(i, (50, 50))
    flipped_image = cv2.flip(image, 1)
    symmetry_score, _ = ssim(image, flipped_image, full=True)
    flipped_class_1_scores.append(symmetry_score)

flipped_class_1_scores = np.array(flipped_class_1_scores)
flipped_class_1_scores_mean = np.mean(flipped_class_1_scores)
flipped_class_1_scores.shape
# Out:
# (5968,)

# %%
flipped_class_2_scores = []

for i in class_2_image:
    image = cv2.resize(i, (50, 50))
    flipped_image = cv2.flip(image, 1)
    symmetry_score, _ = ssim(image, flipped_image, full=True)
    flipped_class_2_scores.append(symmetry_score)

flipped_class_2_scores = np.array(flipped_class_2_scores)
flipped_class_2_scores_mean = np.mean(flipped_class_2_scores)
flipped_class_2_scores.shape
# Out:
# (6030,)

# %%
print(f'FR0 numbers: {flipped_class_0_scores.shape} , FRI Numbers: {flipped_class_1_scores.shape}, FRII Numbers: {flipped_class_2_scores.shape}')
print(f'FR0 Symmetry Score: {flipped_class_0_scores_mean:0.2f} , FRI Symmetry Score: {flipped_class_1_scores_mean:0.2f}, FRII Symmetry Score: {flipped_class_2_scores_mean:0.2f}')


flipped_labels = ['FR0', 'FRI', 'FRII']
flipped_values = [flipped_class_0_scores_mean, flipped_class_1_scores_mean, flipped_class_2_scores_mean]
plt.bar(flipped_labels, flipped_values)
plt.show()
# Out:
# FR0 numbers: (5972,) , FRI Numbers: (5968,), FRII Numbers: (6030,)
# FR0 Symmetry Score: 0.95 , FRI Symmetry Score: 0.82, FRII Symmetry Score: 0.70

# %% [markdown]
# #**Normalization**

# %%
np.min(final_data[0]), np.max(final_data[0])
# Out:
# (0, 248)

# %%
data_normalized = final_data / 255

# %%
print(f'Min of original = {np.min(final_data[0])}')
print(f'Max of original = {np.max(final_data[0])}')
print(f'Min of original = {np.min(data_normalized[0])}')
print(f'Max of original = {np.max(data_normalized[0])}')
# Out:
# Min of original = 0
# Max of original = 248
# Min of original = 0.0
# Max of original = 0.9725490196078431

# %% [markdown]
# #**Splitting**

# %%
x = data_normalized
y = final_labels
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((12579, 60, 60, 1), (12579,), (5391, 60, 60, 1), (5391,))

# %% [markdown]
# #**Augmentation**

# %%
datagen = ImageDataGenerator(rotation_range=30,
                             width_shift_range=0.2,
                             height_shift_range=0.2,
                             zoom_range=0.2,
                             shear_range=0.2,
                             horizontal_flip=True,
                             fill_mode='nearest')
class_2_data = filtered_data[filtered_labels == 2]
class_1_data = filtered_data[filtered_labels == 1]


augmented_class_2_data = []
augmented_class_2_labels = []

for i in range(4000):
    image = class_2_data[np.random.randint(0, len(class_2_data))]
    augmented_image = datagen.random_transform(image)
    augmented_class_2_data.append(augmented_image)
    augmented_class_2_labels.append(2)



augmented_class_1_data = []
augmented_class_1_labels = []

for i in range(1000):
    image = class_1_data[np.random.randint(0, len(class_1_data))]
    augmented_image = datagen.random_transform(image)
    augmented_class_1_data.append(augmented_image)
    augmented_class_1_labels.append(1)

# %%
augmented_class_2_data = np.array(augmented_class_2_data)
augmented_class_2_labels = np.array(augmented_class_2_labels)

augmented_class_1_data = np.array(augmented_class_1_data)
augmented_class_1_labels = np.array(augmented_class_1_labels)

final_data = np.concatenate((filtered_data, augmented_class_2_data, augmented_class_1_data), axis=0)
final_labels = np.concatenate((filtered_labels, augmented_class_2_labels, augmented_class_1_labels), axis=0)

# %%
print("Final data shape:", final_data.shape)
print("Final labels shape:", final_labels.shape)
# Out:
# Final data shape: (17970, 60, 60, 1)
# Final labels shape: (17970,)

# %%
counter = Counter(final_labels)
sorted_counts = dict(sorted(counter.items()))
plt.bar(sorted_counts.keys(), sorted_counts.values(), color='skyblue')
plt.grid(True)
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Count of Each Class in the Dataset')
plt.xticks(range(3))
plt.show()

# %% [markdown]
# #**CNN**

# %% [markdown]
# ##**CNN Architecture**

# %%
model_cnn = keras.Sequential()

#Seed
tf.random.set_seed(42)

#CNN
model_cnn.add(keras.layers.Conv2D(8, kernel_size=(3,3), input_shape=(60, 60, 1)))
model_cnn.add(keras.layers.BatchNormalization())
model_cnn.add(keras.layers.Activation('relu'))

model_cnn.add(keras.layers.Conv2D(16, kernel_size=(3,3)))
model_cnn.add(keras.layers.BatchNormalization())
model_cnn.add(keras.layers.Activation('relu'))
model_cnn.add(keras.layers.MaxPooling2D(pool_size=(2, 2)))

model_cnn.add(keras.layers.Conv2D(16, kernel_size=(3,3)))
model_cnn.add(keras.layers.BatchNormalization())
model_cnn.add(keras.layers.Activation('relu'))

model_cnn.add(keras.layers.Conv2D(32, kernel_size=(3,3)))
model_cnn.add(keras.layers.BatchNormalization())
model_cnn.add(keras.layers.Activation('relu'))
model_cnn.add(keras.layers.MaxPooling2D(pool_size=(2, 2)))

model_cnn.add(keras.layers.Conv2D(64, kernel_size=(3,3)))
model_cnn.add(keras.layers.BatchNormalization())
model_cnn.add(keras.layers.Activation('relu'))
model_cnn.add(keras.layers.MaxPool2D(pool_size=(2, 2)))

model_cnn.add(keras.layers.Conv2D(64, kernel_size=(3,3)))
model_cnn.add(keras.layers.BatchNormalization())
model_cnn.add(keras.layers.Activation('relu'))

model_cnn.add(keras.layers.Conv2D(128, kernel_size=(3,3)))
model_cnn.add(keras.layers.BatchNormalization())
model_cnn.add(keras.layers.Activation('relu'))


#Dense
model_cnn.add(keras.layers.Flatten())
model_cnn.add(keras.layers.Dense(units=64, activation='relu'))
model_cnn.add(keras.layers.Dropout(0.5))



#Output
model_cnn.add(keras.layers.Dense(units=3, activation=keras.activations.softmax))


#Model Compiling
optimizer = keras.optimizers.Adam(learning_rate=0.000009)
loss = keras.losses.SparseCategoricalCrossentropy()
metric = [keras.metrics.CategoricalAccuracy()]

model_cnn.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])


#Builing and Summury
model_cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 58, 58, 8)         80
#
#  batch_normalization (BatchN  (None, 58, 58, 8)        32
#  ormalization)
#
#  activation (Activation)     (None, 58, 58, 8)         0
#
#  conv2d_1 (Conv2D)           (None, 56, 56, 16)        1168
#
#  batch_normalization_1 (Batc  (None, 56, 56, 16)       64
#  hNormalization)
#
#  activation_1 (Activation)   (None, 56, 56, 16)        0
#
#  max_pooling2d (MaxPooling2D  (None, 28, 28, 16)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 26, 26, 16)        2320
#
#  batch_normalization_2 (Batc  (None, 26, 26, 16)       64
#  hNormalization)
#
#  activation_2 (Activation)   (None, 26, 26, 16)        0
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 32)        4640
#
#  batch_normalization_3 (Batc  (None, 24, 24, 32)       128
#  hNormalization)
#
#  activation_3 (Activation)   (None, 24, 24, 32)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 10, 10, 64)        18496
#
#  batch_normalization_4 (Batc  (None, 10, 10, 64)       256
#  hNormalization)
#
#  activation_4 (Activation)   (None, 10, 10, 64)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 3, 3, 64)          36928
#
#  batch_normalization_5 (Batc  (None, 3, 3, 64)         256
#  hNormalization)
#
#  activation_5 (Activation)   (None, 3, 3, 64)          0
#
#  conv2d_6 (Conv2D)           (None, 1, 1, 128)         73856
#
#  batch_normalization_6 (Batc  (None, 1, 1, 128)        512
#  hNormalization)
#
#  activation_6 (Activation)   (None, 1, 1, 128)         0
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 64)                8256
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 147,251
# Trainable params: 146,595
# Non-trainable params: 656
# _________________________________________________________________

# %% [markdown]
# ##**Early Stopping**

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=37, restore_best_weights=True)

# %% [markdown]
# ##**CNN Fitting**

# %%
from sklearn.utils.class_weight import compute_class_weight

# Compute class weights
classes = np.unique(labels)  # Replace `labels` with your true labels
class_weights = compute_class_weight('balanced', classes=classes, y=labels)
class_weight_dict = {i: weight for i, weight in enumerate(class_weights)}
print("Class Weights:", class_weight_dict)
# Out:
# Class Weights: {0: 0.722057368941642, 1: 0.8746006389776357, 2: 2.1200387221684416}

# %%
class_weight_dict = {0: 1.0, 1: 2.5, 2: 1.5}  # Higher weight for class 1

# %%
start = time.perf_counter()
hist = model_cnn.fit(x_train,
                     y_train,
                     batch_size=512,
                     epochs=200,
                     validation_data=(x_test, y_test),
                     callbacks=[early_stopping],
                     class_weight=class_weight_dict )
end = time.perf_counter()
# Out:
# Epoch 1/200
# 25/25 [==============================] - 12s 63ms/step - loss: 2.1462 - accuracy: 0.3812 - val_loss: 1.0995 - val_accuracy: 0.3398
# Epoch 2/200
# 25/25 [==============================] - 1s 33ms/step - loss: 1.9324 - accuracy: 0.4752 - val_loss: 1.1030 - val_accuracy: 0.3398
# Epoch 3/200
# 25/25 [==============================] - 1s 32ms/step - loss: 1.8253 - accuracy: 0.5358 - val_loss: 1.1085 - val_accuracy: 0.3398
# Epoch 4/200
# 25/25 [==============================] - 1s 32ms/step - loss: 1.7066 - accuracy: 0.5728 - val_loss: 1.1142 - val_accuracy: 0.3398
# Epoch 5/200
# 25/25 [==============================] - 1s 33ms/step - loss: 1.6402 - accuracy: 0.5931 - val_loss: 1.1193 - val_accuracy: 0.3398
# Epoch 6/200
# 25/25 [==============================] - 1s 32ms/step - loss: 1.5846 - accuracy: 0.6160 - val_loss: 1.1219 - val_accuracy: 0.3398
# Epoch 7/200
# 25/25 [==============================] - 1s 32ms/step - loss: 1.5312 - accuracy: 0.6235 - val_loss: 1.1250 - val_accuracy: 0.3398
# Epoch 8/200
# 25/25 [==============================] - 1s 32ms/step - loss: 1.4762 - accuracy: 0.6365 - val_loss: 1.1262 - val_accuracy: 0.3398
# Epoch 9/200
# 25/25 [==============================] - 1s 33ms/step - loss: 1.4501 - accuracy: 0.6409 - val_loss: 1.1253 - val_accuracy: 0.3398
# Epoch 10/200
# 25/25 [==============================] - 1s 32ms/step - loss: 1.4282 - accuracy: 0.6483 - val_loss: 1.1205 - val_accuracy: 0.3398
# Epoch 11/200
# 25/25 [==============================] - 1s 32ms/step - loss: 1.3875 - accuracy: 0.6560 - val_loss: 1.1146 - val_accuracy: 0.3404
# Epoch 12/200
# 25/25 [==============================] - 1s 33ms/step - loss: 1.3781 - accuracy: 0.6553 - val_loss: 1.1094 - val_accuracy: 0.3437
# Epoch 13/200
# 25/25 [==============================] - 1s 32ms/step - loss: 1.3605 - accuracy: 0.6567 - val_loss: 1.1015 - val_accuracy: 0.3506
# Epoch 14/200
# 25/25 [==============================] - 1s 33ms/step - loss: 1.3204 - accuracy: 0.6700 - val_loss: 1.0885 - val_accuracy: 0.3671
# Epoch 15/200
# 25/25 [==============================] - 1s 33ms/step - loss: 1.3098 - accuracy: 0.6686 - val_loss: 1.0691 - val_accuracy: 0.3964
# Epoch 16/200
# 25/25 [==============================] - 1s 33ms/step - loss: 1.2956 - accuracy: 0.6754 - val_loss: 1.0454 - val_accuracy: 0.4435
# Epoch 17/200
# 25/25 [==============================] - 1s 33ms/step - loss: 1.2905 - accuracy: 0.6780 - val_loss: 1.0213 - val_accuracy: 0.4780
# Epoch 18/200
# 25/25 [==============================] - 1s 33ms/step - loss: 1.2591 - accuracy: 0.6809 - val_loss: 0.9907 - val_accuracy: 0.4986
# Epoch 19/200
# 25/25 [==============================] - 1s 32ms/step - loss: 1.2647 - accuracy: 0.6834 - val_loss: 0.9533 - val_accuracy: 0.5175
# Epoch 20/200
# 25/25 [==============================] - 1s 32ms/step - loss: 1.2403 - accuracy: 0.6795 - val_loss: 0.9113 - val_accuracy: 0.5511
# Epoch 21/200
# 25/25 [==============================] - 1s 32ms/step - loss: 1.2226 - accuracy: 0.6872 - val_loss: 0.8663 - val_accuracy: 0.6062
# Epoch 22/200
# 25/25 [==============================] - 1s 33ms/step - loss: 1.2141 - accuracy: 0.6898 - val_loss: 0.8239 - val_accuracy: 0.6539
# Epoch 23/200
# 25/25 [==============================] - 1s 32ms/step - loss: 1.1960 - accuracy: 0.6919 - val_loss: 0.7819 - val_accuracy: 0.6776
# Epoch 24/200
# 25/25 [==============================] - 1s 34ms/step - loss: 1.1930 - accuracy: 0.6961 - val_loss: 0.7425 - val_accuracy: 0.7004
# Epoch 25/200
# 25/25 [==============================] - 1s 33ms/step - loss: 1.1730 - accuracy: 0.6968 - val_loss: 0.7064 - val_accuracy: 0.7210
# Epoch 26/200
# 25/25 [==============================] - 1s 33ms/step - loss: 1.1618 - accuracy: 0.6991 - val_loss: 0.6774 - val_accuracy: 0.7340
# Epoch 27/200
# 25/25 [==============================] - 1s 33ms/step - loss: 1.1587 - accuracy: 0.7004 - val_loss: 0.6572 - val_accuracy: 0.7405
# Epoch 28/200
# 25/25 [==============================] - 1s 32ms/step - loss: 1
# 25/25 [==============================] - 1s 33ms/step - loss: 0.6227 - accuracy: 0.8540 - val_loss: 0.4766 - val_accuracy: 0.8091

# %%
(end - start)/ 60
# Out:
# 2.907779718333404

# %%
acc_train = hist.history['accuracy']
acc_test = hist.history['val_accuracy']

plt.axes().set_facecolor('gray')
plt.grid('True')

plt.plot(acc_train, color='blue', label='Train acc')
plt.plot(acc_test, color='red', label='Test acc')

plt.legend()
plt.show()

# %%
loss_train = hist.history['loss']
loss_test = hist.history['val_loss']

plt.axes().set_facecolor('gray')
plt.grid('True')


plt.plot(loss_train, color='blue', label='Train loss');
plt.plot(loss_test, color='red', label='Test loss');

# %%
model_cnn.evaluate(x=x_test, y=y_test)
model_cnn.evaluate(x=x_train, y=y_train)
# Out:
# 169/169 [==============================] - 1s 4ms/step - loss: 0.4767 - accuracy: 0.8091
# 394/394 [==============================] - 2s 4ms/step - loss: 0.3334 - accuracy: 0.8808
# [0.3333624005317688, 0.8807536363601685]

# %%
y_pred_train = model_cnn.predict(x_train)
y_pred_test = model_cnn.predict(x_test)


index_train = random.randint(0, 12579)
print(f'y_train: {y_train[index_train]} y_pred_train:{y_pred_train[index_train]}')

index_test = random.randint(0, 5391)
print(f'y_test: {y_test[index_test]} y_pred_test:{y_pred_test[index_test]}')
# Out:
# 394/394 [==============================] - 1s 3ms/step
# 169/169 [==============================] - 1s 3ms/step
# y_train: 0 y_pred_train:[0.8013  0.1696  0.02907]
# y_test: 0 y_pred_test:[0.9185   0.07513  0.006355]

# %%
y_pred_train_smax = softmax(y_pred_train, axis=1)
y_pred_test_smax = softmax(y_pred_test, axis=1)

y_pred_train_smax = np.argmax(y_pred_train_smax, axis=1)
y_pred_test_smax = np.argmax(y_pred_test_smax, axis=1)


y_pred_test_smax.shape, y_pred_train_smax.shape
# Out:
# ((5391,), (12579,))

# %%
acc_train = accuracy_score(y_train, y_pred_train_smax)
acc_test = accuracy_score(y_test, y_pred_test_smax)

p = precision_score(y_test, y_pred_test_smax, average='micro')
r = recall_score(y_test, y_pred_test_smax, average='micro')
f1 = f1_score(y_test, y_pred_test_smax, average='micro')


print(f'Acc Train: {acc_train} - Acc Test: {acc_test} - Percision: {p} - Recall: {r} - F1:{f1}')
# Out:
# Acc Train: 0.8807536370140711 - Acc Test: 0.8091263216471898 - Percision: 0.8091263216471898 - Recall: 0.8091263216471898 - F1:0.8091263216471898

# %%
cm_train = confusion_matrix(y_true=y_train, y_pred=y_pred_train_smax)
disp_cm_train = ConfusionMatrixDisplay(cm_train)

cm_train = cm_train.astype('float') / cm_train.sum(axis=1)[:, np.newaxis]
disp_cm_train_perce = ConfusionMatrixDisplay(cm_train)


fig , (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
ax1.set_title('Values')
ax2.set_title('Percentage')
disp_cm_train.plot(ax=ax1);
disp_cm_train_perce.plot(ax=ax2);

# %%
cm_test = confusion_matrix(y_true=y_test, y_pred=y_pred_test_smax)
disp_cm_test = ConfusionMatrixDisplay(cm_test)

cm_test = cm_test.astype('float') / cm_test.sum(axis=1)[:, np.newaxis]
disp_cm_test_perce = ConfusionMatrixDisplay(cm_test)


fig , (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
ax1.set_title('Values')
ax2.set_title('Percentage')
disp_cm_test.plot(ax=ax1);
disp_cm_test_perce.plot(ax=ax2);
